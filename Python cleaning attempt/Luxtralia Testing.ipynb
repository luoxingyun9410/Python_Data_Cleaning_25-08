# %%
! pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 KB 34.4 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np

data = pd.read_excel("Luxtralia test/2021 Journal & GL review.xlsx",sheet_name="2.LuxGL")
data
# Out:
#         Company  Division  BOA  VoucherNo  Year FamId  FamFun VoucherDesp  \
# 0           100     680.0   10   10050752  2021  GL01     100     JRNLVCH
# 1           100     680.0   10   10050751  2021  GL01     100     JRNLVCH
# 2           100     680.0   10   10050752  2021  GL01     100     JRNLVCH
# 3           100     680.0   10   10050759  2021  GL01     100     JRNLVCH
# 4           100     680.0   62   62256392  2021  GL01     992     GLUPLO
# ...         ...       ...  ...        ...   ...   ...     ...         ...
# 273863      100     680.0   62   62245697  2021  GL01     992     GLUPLO
# 273864      100     680.0   62   62245698  2021  GL01     992     GLUPLO
# 273865      100     680.0   38   38018699  2021  AP32     100     PP-PMT
# 273866      100     680.0   38   38018699  2021  AP32     100     PP-PMT
# 273867      100       NaN   38   38018699  2021  AP32     100     PP-PMT
#
#         AccountingDate  AccountCode   ... ReconcilaitionDate ReconcilaitionNo  \
# 0             20210930        111911  ...                  0              NaN
# 1             20210930        112571  ...           20210930              3.0
# 2             20210930        112571  ...                  0              NaN
# 3             20210930        112571  ...                  0              NaN
# 4             20210930        121010  ...                  0              NaN
# ...                ...           ...  ...                ...              ...
# 273863        20201001        538020  ...                  0              NaN
# 273864        20201001        538020  ...                  0              NaN
# 273865        20201001        126186  ...                  0              NaN
# 273866        20201001        221110  ...           20201001              NaN
# 273867        20201001        221110  ...           20201001              NaN
#
#          EnteredBy                                  Username EntryDate  \
# 0       ISC0780     SITI FATIMAH BINTI OMAR                   20211022
# 1       ISC0780     SITI FATIMAH BINTI OMAR                   20211022
# 2       ISC0780     SITI FATIMAH BINTI OMAR                   20211022
# 3       ISC0780     SITI FATIMAH BINTI OMAR                   20211022
# 4       ISC0780     SITI FATIMAH BINTI OMAR                   20211022
# ...            ...                                       ...       ...
# 273863  V005046     NURUL ELIZA BINTI RAMLI                   20201002
# 273864  V005046     NURUL ELIZA BINTI RAMLI                   20201002
# 273865  EES0009     MEGHALA                                   20201001
# 273866  EES0009     MEGHALA                                   20201001
# 273867  EES0009     MEGHALA                                   20201001
#
#        EntryDate.1  Day Unnamed: 36  Unnamed: 37 Unnamed: 38
# 0       22/10/2021  Fri         NaN          NaN         NaN
# 1       22/10/2021  Fri         NaN          NaN         NaN
# 2       22/10/2021  Fri         NaN          NaN         NaN
# 3       22/10/2021  Fri         NaN          NaN         NaN
# 4       22/10/2021  Fri         NaN          NaN         NaN
# ...            ...  ...         ...          ...         ...
# 273863  02/10/2020  Fri         NaN          NaN         NaN
# 273864  02/10/2020  Fri         NaN          NaN         NaN
# 273865  01/10/2020  Thu         NaN          NaN         NaN
# 273866  01/10/2020  Thu         NaN          NaN         NaN
# 273867  01/10/2020  Thu         NaN          NaN         NaN
#
# [273868 rows x 39 columns]

# %%
data.nunique()
# Out:
# Company                      1
# Division                     1
# BOA                         19
# VoucherNo                22584
# Year                         2
# FamId                       11
# FamFun                      13
# VoucherDesp                 33
# AccountingDate             365
# AccountCode                247
# AccountCodeDesp            247
# DIM2                        40
# DIM3                       234
# DIM4                       240
# DIM5                       387
# DIM6                      7447
# DIM7                       105
# VoucherTxt               31300
# VatCode                     10
# VatCodeDesp                  6
# VatRate1                     2
# VatRate2                     1
# Vat/GstAmt1              22362
# Vat/GstAmt2                  1
# LocalAmt                109242
# Currency                     9
# ExchangeRate                76
# ForeignCurr             108824
# ReconciliationStatus         3
# ReconcilaitionDate         260
# ReconcilaitionNo          1619
# EnteredBy                   58
# Username                    58
# EntryDate                  383
# EntryDate.1                383
# Day                          7
# Unnamed: 36                  0
# Unnamed: 37                  0
# Unnamed: 38                  0
# dtype: int64

# %%
columns_to_drop = data.nunique()[data.nunique() == 1].index
columns_to_drop
# Out:
# Index(['Company', 'Division', 'VatRate2', 'Vat/GstAmt2'], dtype='object')

# %%
data_dropped_cols = data.copy()
data_dropped_cols = data_dropped_cols.drop(columns=columns_to_drop)
data_dropped_cols
# Out:
#         BOA  VoucherNo  Year FamId  FamFun VoucherDesp  AccountingDate  \
# 0        10   10050752  2021  GL01     100     JRNLVCH        20210930
# 1        10   10050751  2021  GL01     100     JRNLVCH        20210930
# 2        10   10050752  2021  GL01     100     JRNLVCH        20210930
# 3        10   10050759  2021  GL01     100     JRNLVCH        20210930
# 4        62   62256392  2021  GL01     992     GLUPLO         20210930
# ...     ...        ...   ...   ...     ...         ...             ...
# 273863   62   62245697  2021  GL01     992     GLUPLO         20201001
# 273864   62   62245698  2021  GL01     992     GLUPLO         20201001
# 273865   38   38018699  2021  AP32     100     PP-PMT         20201001
# 273866   38   38018699  2021  AP32     100     PP-PMT         20201001
# 273867   38   38018699  2021  AP32     100     PP-PMT         20201001
#
#         AccountCode                            AccountCodeDesp        DIM2  \
# 0             111911  RIGHT-OF-USE ASSET                        OFF
# 1             112571  ACC DEPRECIATION-RIGHT-OF-USE ASSET       OFF
# 2             112571  ACC DEPRECIATION-RIGHT-OF-USE ASSET       OFF
# 3             112571  ACC DEPRECIATION-RIGHT-OF-USE ASSET       OFF
# 4             121010  INVENTORIES                               BBW
# ...              ...                                       ...         ...
# 273863        538020  REPAIR & MAINTENANCE-GENERAL              VCS
# 273864        538020  REPAIR & MAINTENANCE-GENERAL              BBW
# 273865        126186  WESTPAC (MARKET & CLEARANCE STS)          NA
# 273866        221110  TRADE CREDITORS                           FO
# 273867        221110  TRADE CREDITORS                           FO
#
#         ... ReconcilaitionDate ReconcilaitionNo   EnteredBy  \
# 0       ...                  0              NaN  ISC0780
# 1       ...           20210930              3.0  ISC0780
# 2       ...                  0              NaN  ISC0780
# 3       ...                  0              NaN  ISC0780
# 4       ...                  0              NaN  ISC0780
# ...     ...                ...              ...         ...
# 273863  ...                  0              NaN  V005046
# 273864  ...                  0              NaN  V005046
# 273865  ...                  0              NaN  EES0009
# 273866  ...           20201001              NaN  EES0009
# 273867  ...           20201001              NaN  EES0009
#
#                                         Username EntryDate EntryDate.1  Day  \
# 0       SITI FATIMAH BINTI OMAR                   20211022  22/10/2021  Fri
# 1       SITI FATIMAH BINTI OMAR                   20211022  22/10/2021  Fri
# 2       SITI FATIMAH BINTI OMAR                   20211022  22/10/2021  Fri
# 3       SITI FATIMAH BINTI OMAR                   20211022  22/10/2021  Fri
# 4       SITI FATIMAH BINTI OMAR                   20211022  22/10/2021  Fri
# ...                                          ...       ...         ...  ...
# 273863  NURUL ELIZA BINTI RAMLI                   20201002  02/10/2020  Fri
# 273864  NURUL ELIZA BINTI RAMLI                   20201002  02/10/2020  Fri
# 273865  MEGHALA                                   20201001  01/10/2020  Thu
# 273866  MEGHALA                                   20201001  01/10/2020  Thu
# 273867  MEGHALA                                   20201001  01/10/2020  Thu
#
#        Unnamed: 36  Unnamed: 37  Unnamed: 38
# 0              NaN          NaN          NaN
# 1              NaN          NaN          NaN
# 2              NaN          NaN          NaN
# 3              NaN          NaN          NaN
# 4              NaN          NaN          NaN
# ...            ...          ...          ...
# 273863         NaN          NaN          NaN
# 273864         NaN          NaN          NaN
# 273865         NaN          NaN          NaN
# 273866         NaN          NaN          NaN
# 273867         NaN          NaN          NaN
#
# [273868 rows x 35 columns]

# %%
data_dropped_cols = data_dropped_cols.dropna(axis=1, how='all')
data_dropped_cols
# Out:
#         BOA  VoucherNo  Year FamId  FamFun VoucherDesp  AccountingDate  \
# 0        10   10050752  2021  GL01     100     JRNLVCH        20210930
# 1        10   10050751  2021  GL01     100     JRNLVCH        20210930
# 2        10   10050752  2021  GL01     100     JRNLVCH        20210930
# 3        10   10050759  2021  GL01     100     JRNLVCH        20210930
# 4        62   62256392  2021  GL01     992     GLUPLO         20210930
# ...     ...        ...   ...   ...     ...         ...             ...
# 273863   62   62245697  2021  GL01     992     GLUPLO         20201001
# 273864   62   62245698  2021  GL01     992     GLUPLO         20201001
# 273865   38   38018699  2021  AP32     100     PP-PMT         20201001
# 273866   38   38018699  2021  AP32     100     PP-PMT         20201001
# 273867   38   38018699  2021  AP32     100     PP-PMT         20201001
#
#         AccountCode                            AccountCodeDesp        DIM2  \
# 0             111911  RIGHT-OF-USE ASSET                        OFF
# 1             112571  ACC DEPRECIATION-RIGHT-OF-USE ASSET       OFF
# 2             112571  ACC DEPRECIATION-RIGHT-OF-USE ASSET       OFF
# 3             112571  ACC DEPRECIATION-RIGHT-OF-USE ASSET       OFF
# 4             121010  INVENTORIES                               BBW
# ...              ...                                       ...         ...
# 273863        538020  REPAIR & MAINTENANCE-GENERAL              VCS
# 273864        538020  REPAIR & MAINTENANCE-GENERAL              BBW
# 273865        126186  WESTPAC (MARKET & CLEARANCE STS)          NA
# 273866        221110  TRADE CREDITORS                           FO
# 273867        221110  TRADE CREDITORS                           FO
#
#         ... ExchangeRate ForeignCurr ReconciliationStatus ReconcilaitionDate  \
# 0       ...          1.0   459314.00                    0                  0
# 1       ...          1.0  6638805.00                    9           20210930
# 2       ...          1.0 -8747287.00                    0                  0
# 3       ...          1.0        2.00                    0                  0
# 4       ...          1.0     -495.10                    0                  0
# ...     ...          ...         ...                  ...                ...
# 273863  ...          1.0      225.54                    0                  0
# 273864  ...          1.0      286.75                    0                  0
# 273865  ...          1.0     -605.00                    0                  0
# 273866  ...          1.0     -330.00                    9           20201001
# 273867  ...          1.0      935.00                    9           20201001
#
#        ReconcilaitionNo   EnteredBy                                  Username  \
# 0                   NaN  ISC0780     SITI FATIMAH BINTI OMAR
# 1                   3.0  ISC0780     SITI FATIMAH BINTI OMAR
# 2                   NaN  ISC0780     SITI FATIMAH BINTI OMAR
# 3                   NaN  ISC0780     SITI FATIMAH BINTI OMAR
# 4                   NaN  ISC0780     SITI FATIMAH BINTI OMAR
# ...                 ...         ...                                       ...
# 273863              NaN  V005046     NURUL ELIZA BINTI RAMLI
# 273864              NaN  V005046     NURUL ELIZA BINTI RAMLI
# 273865              NaN  EES0009     MEGHALA
# 273866              NaN  EES0009     MEGHALA
# 273867              NaN  EES0009     MEGHALA
#
#        EntryDate  EntryDate.1  Day
# 0       20211022   22/10/2021  Fri
# 1       20211022   22/10/2021  Fri
# 2       20211022   22/10/2021  Fri
# 3       20211022   22/10/2021  Fri
# 4       20211022   22/10/2021  Fri
# ...          ...          ...  ...
# 273863  20201002   02/10/2020  Fri
# 273864  20201002   02/10/2020  Fri
# 273865  20201001   01/10/2020  Thu
# 273866  20201001   01/10/2020  Thu
# 273867  20201001   01/10/2020  Thu
#
# [273868 rows x 32 columns]

# %%
data_dropped_cols.dtypes
# Out:
# BOA                       int64
# VoucherNo                 int64
# Year                      int64
# FamId                    object
# FamFun                    int64
# VoucherDesp              object
# AccountingDate            int64
# AccountCode               int64
# AccountCodeDesp          object
# DIM2                     object
# DIM3                     object
# DIM4                     object
# DIM5                     object
# DIM6                     object
# DIM7                     object
# VoucherTxt               object
# VatCode                   int64
# VatCodeDesp              object
# VatRate1                  int64
# Vat/GstAmt1             float64
# LocalAmt                float64
# Currency                 object
# ExchangeRate            float64
# ForeignCurr             float64
# ReconciliationStatus      int64
# ReconcilaitionDate        int64
# ReconcilaitionNo        float64
# EnteredBy                object
# Username                 object
# EntryDate                 int64
# EntryDate.1              object
# Day                      object
# dtype: object

# %%
missing_values = [np.nan, "", " ", None]

data_dropped_cols.isin(missing_values).mean().sort_values(ascending=False) * 100
# Out:
# ReconcilaitionNo        87.932508
# VatCodeDesp              0.045642
# BOA                      0.000000
# VoucherNo                0.000000
# EntryDate.1              0.000000
# EntryDate                0.000000
# Username                 0.000000
# EnteredBy                0.000000
# ReconcilaitionDate       0.000000
# ReconciliationStatus     0.000000
# ForeignCurr              0.000000
# ExchangeRate             0.000000
# Currency                 0.000000
# LocalAmt                 0.000000
# Vat/GstAmt1              0.000000
# VatRate1                 0.000000
# VatCode                  0.000000
# VoucherTxt               0.000000
# DIM7                     0.000000
# DIM6                     0.000000
# DIM5                     0.000000
# DIM4                     0.000000
# DIM3                     0.000000
# DIM2                     0.000000
# AccountCodeDesp          0.000000
# AccountCode              0.000000
# AccountingDate           0.000000
# VoucherDesp              0.000000
# FamFun                   0.000000
# FamId                    0.000000
# Year                     0.000000
# Day                      0.000000
# dtype: float64

# %%
columns_to_drop = data_dropped_cols.isin(missing_values).mean()[(data_dropped_cols.isin(missing_values).mean()) > 0.86].index
data_missing_values = data_dropped_cols.copy()
data_missing_values = data_dropped_cols.drop(columns=columns_to_drop)
data_missing_values
# Out:
#         BOA  VoucherNo  Year FamId  FamFun VoucherDesp  AccountingDate  \
# 0        10   10050752  2021  GL01     100     JRNLVCH        20210930
# 1        10   10050751  2021  GL01     100     JRNLVCH        20210930
# 2        10   10050752  2021  GL01     100     JRNLVCH        20210930
# 3        10   10050759  2021  GL01     100     JRNLVCH        20210930
# 4        62   62256392  2021  GL01     992     GLUPLO         20210930
# ...     ...        ...   ...   ...     ...         ...             ...
# 273863   62   62245697  2021  GL01     992     GLUPLO         20201001
# 273864   62   62245698  2021  GL01     992     GLUPLO         20201001
# 273865   38   38018699  2021  AP32     100     PP-PMT         20201001
# 273866   38   38018699  2021  AP32     100     PP-PMT         20201001
# 273867   38   38018699  2021  AP32     100     PP-PMT         20201001
#
#         AccountCode                            AccountCodeDesp        DIM2  \
# 0             111911  RIGHT-OF-USE ASSET                        OFF
# 1             112571  ACC DEPRECIATION-RIGHT-OF-USE ASSET       OFF
# 2             112571  ACC DEPRECIATION-RIGHT-OF-USE ASSET       OFF
# 3             112571  ACC DEPRECIATION-RIGHT-OF-USE ASSET       OFF
# 4             121010  INVENTORIES                               BBW
# ...              ...                                       ...         ...
# 273863        538020  REPAIR & MAINTENANCE-GENERAL              VCS
# 273864        538020  REPAIR & MAINTENANCE-GENERAL              BBW
# 273865        126186  WESTPAC (MARKET & CLEARANCE STS)          NA
# 273866        221110  TRADE CREDITORS                           FO
# 273867        221110  TRADE CREDITORS                           FO
#
#         ... Currency ExchangeRate ForeignCurr ReconciliationStatus  \
# 0       ...      AUD          1.0   459314.00                    0
# 1       ...      AUD          1.0  6638805.00                    9
# 2       ...      AUD          1.0 -8747287.00                    0
# 3       ...      AUD          1.0        2.00                    0
# 4       ...      AUD          1.0     -495.10                    0
# ...     ...      ...          ...         ...                  ...
# 273863  ...      AUD          1.0      225.54                    0
# 273864  ...      AUD          1.0      286.75                    0
# 273865  ...      AUD          1.0     -605.00                    0
# 273866  ...      AUD          1.0     -330.00                    9
# 273867  ...      AUD          1.0      935.00                    9
#
#        ReconcilaitionDate   EnteredBy  \
# 0                       0  ISC0780
# 1                20210930  ISC0780
# 2                       0  ISC0780
# 3                       0  ISC0780
# 4                       0  ISC0780
# ...                   ...         ...
# 273863                  0  V005046
# 273864                  0  V005046
# 273865                  0  EES0009
# 273866           20201001  EES0009
# 273867           20201001  EES0009
#
#                                         Username EntryDate  EntryDate.1  Day
# 0       SITI FATIMAH BINTI OMAR                   20211022   22/10/2021  Fri
# 1       SITI FATIMAH BINTI OMAR                   20211022   22/10/2021  Fri
# 2       SITI FATIMAH BINTI OMAR                   20211022   22/10/2021  Fri
# 3       SITI FATIMAH BINTI OMAR                   20211022   22/10/2021  Fri
# 4       SITI FATIMAH BINTI OMAR                   20211022   22/10/2021  Fri
# ...                                          ...       ...          ...  ...
# 273863  NURUL ELIZA BINTI RAMLI                   20201002   02/10/2020  Fri
# 273864  NURUL ELIZA BINTI RAMLI                   20201002   02/10/2020  Fri
# 273865  MEGHALA                                   20201001   01/10/2020  Thu
# 273866  MEGHALA                                   20201001   01/10/2020  Thu
# 273867  MEGHALA                                   20201001   01/10/2020  Thu
#
# [273868 rows x 31 columns]

# %%
missing_values = [np.nan, "", " ", None]

data_missing_values.isin(missing_values).mean().sort_values(ascending=False) * 100
# Out:
# VatCodeDesp             0.045642
# BOA                     0.000000
# VatCode                 0.000000
# EntryDate.1             0.000000
# EntryDate               0.000000
# Username                0.000000
# EnteredBy               0.000000
# ReconcilaitionDate      0.000000
# ReconciliationStatus    0.000000
# ForeignCurr             0.000000
# ExchangeRate            0.000000
# Currency                0.000000
# LocalAmt                0.000000
# Vat/GstAmt1             0.000000
# VatRate1                0.000000
# VoucherTxt              0.000000
# VoucherNo               0.000000
# DIM7                    0.000000
# DIM6                    0.000000
# DIM5                    0.000000
# DIM4                    0.000000
# DIM3                    0.000000
# DIM2                    0.000000
# AccountCodeDesp         0.000000
# AccountCode             0.000000
# AccountingDate          0.000000
# VoucherDesp             0.000000
# FamFun                  0.000000
# FamId                   0.000000
# Year                    0.000000
# Day                     0.000000
# dtype: float64

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d97f13db-3762-4b9c-8873-be61541cc7eb' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
